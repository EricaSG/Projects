# %% [markdown]
# # Data Understanding: Exploratory Data Anaylsis

# %% [markdown]
# ### Import Relevant Libraries and Import Dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score, recall_score, f1_score, roc_curve, auc

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Terry_Cleaned.csv')
df.head()
# Out:
#    Unnamed: 0 Subject Age Group     GO / SC Num  Terry Stop ID  \
# 0           0             26-35  20140000120677          92317
# 1           1             26-35  20150000001463          28806
# 2           2             26-35  20150000001516          29599
# 3           3             26-35  20150000001670          32260
# 4           4             26-35  20150000001739          33155
#
#   Stop Resolution Officer ID  Officer YOB Officer Gender  \
# 0          Arrest     7500           1984              M
# 1   Field Contact     5670           1965              M
# 2   Field Contact     4844           1961              M
# 3   Field Contact     7539           1963              M
# 4   Field Contact     6973           1977              M
#
#                 Officer Race     Subject Perceived Race  \
# 0  Black or African American                      Asian
# 1                      White                      Other
# 2                      White                      White
# 3                      White                      Other
# 4                      White  Black or African American
#
#   Subject Perceived Gender             Officer Squad Arrest Flag Frisk Flag  \
# 0                     Male  SOUTH PCT 1ST W - ROBERT           N          N
# 1                     Male                       NaN           N          N
# 2                     Male                       NaN           N          N
# 3                     Male                       NaN           N          N
# 4                     Male                       NaN           N          N
#
#    Weapon  Call Made  Year Reported
# 0       0          0           2015
# 1       0          0           2015
# 2       0          0           2015
# 3       0          0           2015
# 4       0          0           2015

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df.head()
# Out:
#   Subject Age Group     GO / SC Num  Terry Stop ID Stop Resolution Officer ID  \
# 0             26-35  20140000120677          92317          Arrest     7500
# 1             26-35  20150000001463          28806   Field Contact     5670
# 2             26-35  20150000001516          29599   Field Contact     4844
# 3             26-35  20150000001670          32260   Field Contact     7539
# 4             26-35  20150000001739          33155   Field Contact     6973
#
#    Officer YOB Officer Gender               Officer Race  \
# 0         1984              M  Black or African American
# 1         1965              M                      White
# 2         1961              M                      White
# 3         1963              M                      White
# 4         1977              M                      White
#
#       Subject Perceived Race Subject Perceived Gender  \
# 0                      Asian                     Male
# 1                      Other                     Male
# 2                      White                     Male
# 3                      Other                     Male
# 4  Black or African American                     Male
#
#               Officer Squad Arrest Flag Frisk Flag  Weapon  Call Made  \
# 0  SOUTH PCT 1ST W - ROBERT           N          N       0          0
# 1                       NaN           N          N       0          0
# 2                       NaN           N          N       0          0
# 3                       NaN           N          N       0          0
# 4                       NaN           N          N       0          0
#
#    Year Reported
# 0           2015
# 1           2015
# 2           2015
# 3           2015
# 4           2015

# %% [markdown]
# ### EDA

# %%
sns.heatmap(df.corr(), annot=True, cmap = 'coolwarm')  #Heatmap with Correlations overlaid on features.

# Scale the Heat Map, so the correlation values are centered and ledgeable
b, t = plt.ylim() # Discover the values for bottom and top
b += 0.5 # Add 0.5 to the bottom
t -= 0.5 # Subtract 0.5 from the top
plt.ylim(b, t) # update the ylim(bottom, top) values
plt.show()

# %%
sns.pairplot(df)

# %%
# Find arrests made by white cops on minorities born before the 80's, born after the 80's
# How many arrest were made by minorities on minorities?
# Were there weapons found, but no arrests made? What race was the subject, what were the circumtances?
# which squad had the most arrests of black people?
# how many arrests resulted from Calls Made?
# how many frisks with no weapons found? How many frisks lead to arrest?

# Does community policing empower racists and the racially baised to call and report false crimes? (revist call types and source from orginal df copy)

# %%
#Do a subplot (hist or bar) gender vs race in subject and officer calls and arrests
# suspicous person calls on suspects by gender and race

# %%
# On average how many white cops stop black people when 
# no calls are made. Is it race or age?
df.loc[(df['Officer Race'] == 'White') & (df['Subject Perceived Race'] == 'Black or African American')]
# Out:
#       Subject Age Group     GO / SC Num  Terry Stop ID Stop Resolution  \
# 4                 26-35  20150000001739          33155   Field Contact
# 5                 26-35  20150000001755          33571   Field Contact
# 16                26-35  20150000002678          49779   Field Contact
# 42                26-35  20150000003506          61980   Field Contact
# 45                26-35  20150000003561          63097   Field Contact
# ...                 ...             ...            ...             ...
# 43059      56 and Above  20200000117523    12809778581   Field Contact
# 43069      56 and Above  20200000143964    13104760486   Field Contact
# 43070      56 and Above  20200000151443    13116539265   Field Contact
# 43072      56 and Above  20200000175347    13267123866  Offense Report
# 43073      56 and Above  20200000175739    13267926443   Field Contact
#
#       Officer ID  Officer YOB Officer Gender Officer Race  \
# 4         6973           1977              M        White
# 5         7402           1973              M        White
# 16        5065           1959              M        White
# 42        8316           1986              M        White
# 45        8316           1986              M        White
# ...          ...          ...            ...          ...
# 43059     8696           1996              M        White
# 43069     8717           1976              F        White
# 43070     6953           1968              M        White
# 43072     8620           1992              M        White
# 43073     8674           1990              M        White
#
#           Subject Perceived Race Subject Perceived Gender  \
# 4      Black or African American                     Male
# 5      Black or African American                     Male
# 16     Black or African American                     Male
# 42     Black or African American                     Male
# 45     Black or African American                     Male
# ...                          ...                      ...
# 43059  Black or African American                     Male
# 43069  Black or African American                     Male
# 43070  Black or African American                     Male
# 43072  Black or African American                     Male
# 43073  Black or African American                     Male
#
#                          Officer Squad Arrest Flag Frisk Flag  Weapon  \
# 4                                  NaN           N          N       0
# 5                                  NaN           N          N       0
# 16         WEST PCT 2ND W - MARY BEATS           N          Y       0
# 42     TRAINING - FIELD TRAINING SQUAD           N          N       0
# 45     TRAINING - FIELD TRAINING SQUAD           N          N       0
# ...                                ...         ...        ...     ...
# 43059     NORTH PCT 3RD W - B/N RELIEF           N          N       1
# 43069  TRAINING - FIELD TRAINING SQUAD           N          Y       1
# 43070           NORTH PCT 2ND W - NORA           N          N       1
# 43072            WEST PCT 3RD W - KING           N          N       1
# 43073      WEST PCT 1ST W - KING/QUEEN           N          N       1
#
#        Call Made  Year Reported
# 4              0           2015
# 5              0           2015
# 16             0           2015
# 42             0           2015
# 45             0           2015
# ...          ...            ...
# 43059          1           2020
# 43069          1           2020
# 43070          1           2020
# 43072          1           2020
# 43073          1           2020
#
# [9941 rows x 16 columns]

# %%
# Does age play a part in racism or bias? 
# Is it race or age?

df.groupby(['Officer YOB', 'Officer Race', 'Subject Perceived Race']).median().head()
# Out:
#                                                      GO / SC Num  \
# Officer YOB Officer Race Subject Perceived Race
# 1900        Unknown      Black or African American  2.019000e+13
#                          Hispanic                   2.018000e+13
#                          Other                      2.019000e+13
#                          Unknown                    2.017000e+13
#                          White                      2.018000e+13
#
#                                                     Terry Stop ID  Weapon  \
# Officer YOB Officer Race Subject Perceived Race
# 1900        Unknown      Black or African American   1.046085e+10     1.0
#                          Hispanic                    4.404070e+05     0.0
#                          Other                       9.134515e+09     1.0
#                          Unknown                     2.728780e+05     0.0
#                          White                       4.045145e+05     0.0
#
#                                                     Call Made  Year Reported
# Officer YOB Officer Race Subject Perceived Race
# 1900        Unknown      Black or African American        0.0         2019.0
#                          Hispanic                         1.0         2018.0
#                          Other                            0.0         2019.0
#                          Unknown                          0.0         2017.0
#                          White                            0.0         2018.0

# %%
# Check Officer Track record, how often are they arresting 
# minorities?

df.groupby(['Officer ID', 'Arrest Flag']).median().head()
# Out:
#                          GO / SC Num  Terry Stop ID  Officer YOB  Weapon  \
# Officer ID Arrest Flag
# -          N            2.019000e+13   1.046085e+10       1900.0     1.0
# -9         N            2.016000e+13   1.931900e+05       1900.0     0.0
# 2768       N            2.015000e+13   6.798700e+04       1949.0     0.0
# 3170       N            2.015000e+13   9.318000e+04       1948.0     0.0
# 4161       N            2.015000e+13   9.128500e+04       1957.0     0.0
#
#                         Call Made  Year Reported
# Officer ID Arrest Flag
# -          N                  0.0         2019.0
# -9         N                  0.0         2016.0
# 2768       N                  1.0         2015.0
# 3170       N                  1.0         2015.0
# 4161       N                  0.0         2015.0

# %%
# How often do police roll up without calls being made?

df.groupby(['Officer Race', 'Subject Perceived Race', 'Call Made']).median().head()
# Out:
#                                                                            GO / SC Num  \
# Officer Race                  Subject Perceived Race           Call Made
# American Indian/Alaska Native American Indian or Alaska Native 0          2.015000e+13
#                                                                1          2.015000e+13
#                               Asian                            0          2.016000e+13
#                                                                1          2.018000e+13
#                               Black or African American        0          2.016000e+13
#
#                                                                           Terry Stop ID  \
# Officer Race                  Subject Perceived Race           Call Made
# American Indian/Alaska Native American Indian or Alaska Native 0               110798.0
#                                                                1                82356.0
#                               Asian                            0               184679.5
#                                                                1               402432.0
#                               Black or African American        0               153327.0
#
#                                                                           Officer YOB  \
# Officer Race                  Subject Perceived Race           Call Made
# American Indian/Alaska Native American Indian or Alaska Native 0               1964.0
#                                                                1               1979.0
#                               Asian                            0               1978.0
#                                                                1               1978.0
#                               Black or African American        0               1978.0
#
#                                                                           Weapon  \
# Officer Race                  Subject Perceived Race           Call Made
# American Indian/Alaska Native American Indian or Alaska Native 0             0.0
#                                                                1             0.0
#                               Asian                            0             0.0
#                                                                1             0.0
#                               Black or African American        0             0.0
#
#                                                                           Year Reported
# Officer Race                  Subject Perceived Race           Call Made
# American Indian/Alaska Native American Indian or Alaska Native 0                 2015.0
#                                                                1                 2015.0
#                               Asian                            0                 2016.0
#                                                                1                 2018.0
#                               Black or African American        0                 2016.0
